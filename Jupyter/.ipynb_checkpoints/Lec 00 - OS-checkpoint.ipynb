# %%
# Read csv Files with Pandas using read_csv()

import pandas as pd
df = pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# Python method getcwd() returns current working directory of a process.

import os

cwd = os.getcwd()

print("Current working directory:", cwd)
# Out:
# Current working directory: C:\Users\user\Desktop\Alaa Saif\Jupyter

# %%
# Driver function

path = r"C:\Users\user\Desktop\Alaa Saif\Jupyter"

for (root,dirs,files) in os.walk(path, topdown=True):
    print (root)
    print (dirs)
    print (files)
    print ('--------------------------------')
# Out:
# C:\Users\user\Desktop\Alaa Saif\Jupyter
# ['.ipynb_checkpoints']
# ['Activity 4 - Array Processing.ipynb', 'Activity 5 - Matrix Product and Multiplication.ipynb', 'Activity 6 - Transpose.ipynb', 'Activity 7 - Series.ipynb', 'Activity1- NumPy(Creating Array).ipynb', 'Activity2- Scalar Operations.ipynb', 'Activity3 - Array Indexin.ipynb', 'data.csv', 'DE_Practice_Project_I_FIFA.ipynb', 'diabetes.csv', 'EX3 - Aggregation and Groupby.ipynb', 'EX3 - Boxplots.ipynb', 'EX3 - Concatenation.ipynb', 'Ex3 - Histogram.ipynb', 'EX3 - Regression plots.ipynb', 'EX3- Missing & Duplicate values.ipynb', 'EX3_Data frame merge.ipynb', 'EX3_Line, bar and PI charts.ipynb', 'EX3_Pivot table.ipynb', 'EX3_Ranking_and_Sorting.ipynb', 'EX3_Statistics.ipynb', 'Exercise2 - Pandas (Data Frames).ipynb', 'Heart_Disease_Dataset_Manipulation.ipynb', 'Heart_Disease_Prediction.csv', 'Lec 00 - OS.ipynb', 'Lec 01 - Creating Arrays.ipynb', 'Lec 04.ipynb', 'Lec 05 - Array Processing.ipynb', 'Lec 06 - Series.ipynb', 'modified_data.csv', 'my_array.txt', 'series_data.txt', 'Untitled.ipynb', 'WorldCups.csv']
# --------------------------------
# C:\Users\user\Desktop\Alaa Saif\Jupyter\.ipynb_checkpoints
# []
# ['Activity 6 - Transpose-checkpoint.ipynb', 'Activity 7 - Series-checkpoint.ipynb', 'DE_Practice_Project_I_FIFA-checkpoint.ipynb', 'EX3 - Aggregation and Groupby-checkpoint.ipynb', 'EX3 - Boxplots-checkpoint.ipynb', 'EX3 - Concatenation-checkpoint.ipynb', 'EX3 - Heatmap-checkpoint.ipynb', 'Ex3 - Histogram-checkpoint.ipynb', 'EX3 - Regression plots-checkpoint.ipynb', 'EX3- Missing & Duplicate values-checkpoint.ipynb', 'Exercise2 - Pandas (Data Frames)-checkpoint.ipynb', 'Exercise2 - Reindexing-checkpoint.ipynb', 'Heart_Disease_Dataset_Manipulation-checkpoint.ipynb', 'Lec 00 - OS-checkpoint.ipynb', 'Lec 06 - Series-checkpoint.ipynb', 'Practice_Project_Diabetes_II-checkpoint.ipynb', 'Untitled-checkpoint.ipynb']
# --------------------------------

# %%
# Get the list of all files and directories
# in the root directory

path = os.getcwd()
dir_list = os.listdir(path)

print("Files and directories in '", path, "' :")
print(dir_list)
# Out:
# Files and directories in ' C:\Users\user\Desktop\Alaa Saif\Jupyter ' :
# ['.ipynb_checkpoints', 'Activity 4 - Array Processing.ipynb', 'Activity 5 - Matrix Product and Multiplication.ipynb', 'Activity 6 - Transpose.ipynb', 'Activity 7 - Series.ipynb', 'Activity1- NumPy(Creating Array).ipynb', 'Activity2- Scalar Operations.ipynb', 'Activity3 - Array Indexin.ipynb', 'data.csv', 'DE_Practice_Project_I_FIFA.ipynb', 'diabetes.csv', 'EX3 - Aggregation and Groupby.ipynb', 'EX3 - Boxplots.ipynb', 'EX3 - Concatenation.ipynb', 'Ex3 - Histogram.ipynb', 'EX3 - Regression plots.ipynb', 'EX3- Missing & Duplicate values.ipynb', 'EX3_Data frame merge.ipynb', 'EX3_Line, bar and PI charts.ipynb', 'EX3_Pivot table.ipynb', 'EX3_Ranking_and_Sorting.ipynb', 'EX3_Statistics.ipynb', 'Exercise2 - Pandas (Data Frames).ipynb', 'Heart_Disease_Dataset_Manipulation.ipynb', 'Heart_Disease_Prediction.csv', 'Lec 00 - OS.ipynb', 'Lec 01 - Creating Arrays.ipynb', 'Lec 04.ipynb', 'Lec 05 - Array Processing.ipynb', 'Lec 06 - Series.ipynb', 'modified_data.csv', 'my_array.txt', 'series_data.txt', 'Untitled.ipynb', 'WorldCups.csv']

# %%
# Directory
directory = "GeeksForGeeks"

# Parent Directory path
parent_dir = "/Users/user/Desktop/Alaa Saif"

# Path
path = os.path.join(parent_dir, directory)

# Create the directory
# 'GeeksForGeeks' in
# '/home / User / Documents'
os.mkdir(path)
print("Directory '%s' created" %directory)
# Out:
# Directory 'GeeksForGeeks' created
